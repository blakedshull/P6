# %% [markdown]
# # Cleaning

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
filename = 'titanic.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Goal is to provide data on survival rate, will drop irrelevant columns

# %%
df.shape
# Out:
# (891, 12)

# %%
df = df.drop(columns=['PassengerId','Cabin'])

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500        S
# 1  female  38.0      1      0          PC 17599  71.2833        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250        S
# 3  female  35.0      1      0            113803  53.1000        S
# 4    male  35.0      0      0            373450   8.0500        S

# %% [markdown]
# ## Correlation heatmap before we switch survived to categorical heatmap

# %%
import seaborn as sns
corr = df.corr()
sns.heatmap(corr, cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Embarked     object
# dtype: object

# %%
df['Survived'].astype(object, copy=False)
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Embarked     object
# dtype: object

# %%
df['Survived'] = df['Survived'].replace(0, 'False')
df['Survived'] = df['Survived'].replace(1, 'True')
df.head()
# Out:
#   Survived  Pclass                                               Name     Sex  \
# 0    False       3                            Braund, Mr. Owen Harris    male
# 1     True       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2     True       3                             Heikkinen, Miss. Laina  female
# 3     True       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4    False       3                           Allen, Mr. William Henry    male
#
#     Age  SibSp  Parch            Ticket     Fare Embarked
# 0  22.0      1      0         A/5 21171   7.2500        S
# 1  38.0      1      0          PC 17599  71.2833        C
# 2  26.0      0      0  STON/O2. 3101282   7.9250        S
# 3  35.0      1      0            113803  53.1000        S
# 4  35.0      0      0            373450   8.0500        S

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df = df.dropna(subset=['Embarked'])
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      0
# dtype: int64

# %%
df.dtypes
# Out:
# Survived     object
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Embarked     object
# dtype: object

# %% [markdown]
# ## Data exploration
# Looking at a few data categories

# %%
df.groupby('Sex')['Survived'].value_counts()
# Out:
# Sex     Survived
# female  True        231
#         False        81
# male    False       468
#         True        109
# Name: Survived, dtype: int64

# %%
df.groupby('Survived')['Fare'].mean()
# Out:
# Survived
# False    22.117887
# True     48.209498
# Name: Fare, dtype: float64

# %%
df.groupby('Survived')['Embarked'].value_counts()
# Out:
# Survived  Embarked
# False     S           427
#           C            75
#           Q            47
# True      S           217
#           C            93
#           Q            30
# Name: Embarked, dtype: int64

# %% [markdown]
# ## Data Viz

# %%
plt.style.use('seaborn')
sns.countplot(data=df, x='Survived')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.boxplot(x='Survived', y='Fare', data=df, showfliers = False) #An outlier is making this hard to see, I'm going to remove them
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %%
sns.boxplot(x='Survived', y='Age', data=df, showfliers = False)
plt.xticks(rotation = 45)
# Out:
# (array([0, 1]), [Text(0, 0, 'False'), Text(1, 0, 'True')])

# %%
sns.boxplot(x='Sex', y='Fare', data=df, showfliers = False)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %%
sns.barplot(x='Survived', y='SibSp', data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='SibSp'>

# %%
sns.barplot(data = df, x = 'Survived', y = 'Age', hue = 'Pclass', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.barplot(data = df, x = 'Pclass', y = 'Fare', hue = 'Survived', edgecolor='black', )
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %%
sns.scatterplot(data=df, x='Age', y='Fare', hue='Survived')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.swarmplot(data=df, x='SibSp', y='Fare', hue='Survived', palette='muted')
# Out:
# C:\Users\Test\anaconda3\envs\dojo-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 81.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Test\anaconda3\envs\dojo-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 54.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Test\anaconda3\envs\dojo-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Test\anaconda3\envs\dojo-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# Data viz is done, will make pipelines and models

# %%
filter1 = df[df['Pclass'] == 1]
titanic1 = filter1.groupby('Sex')['Survived'].value_counts()

plt.pie(titanic1, autopct='%1.0f%%', # Got some of this from here https://www.pythoncharts.com/matplotlib/pie-chart-matplotlib/
        labels = ['Females Survived', 'Females Died', 'Males Survived', 'Males Died'],
        explode = (0, 0, 0, 0))
plt.tight_layout()
plt.title('Rate of Survival in Class 1 by Gender')
plt.rcParams['patch.linewidth'] = 1 # Got this line of code from here: https://stackoverflow.com/questions/20551477/changing-line-properties-in-matplotlib-pie-chart

# %%
titanic1
# Out:
# Sex     Survived
# female  True        89
#         False        3
# male    False       77
#         True        45
# Name: Survived, dtype: int64

# %%
filter2 = df[df['Pclass'] == 2]
titanic2 = filter2.groupby('Sex')['Survived'].value_counts()

plt.pie(titanic2, autopct='%1.0f%%', # Got some of this from here https://www.pythoncharts.com/matplotlib/pie-chart-matplotlib/
        labels = ['Females Survived', 'Females Died', 'Males Died', 'Males Survived'],
        explode = (0, 0, 0, 0))
plt.tight_layout()
plt.title('Rate of Survival in Class 2 by Gender')
plt.rcParams['patch.linewidth'] = 1 # Got this line of code from here: https://stackoverflow.com/questions/20551477/changing-line-properties-in-matplotlib-pie-chart

# %%
titanic2
# Out:
# Sex     Survived
# female  True        70
#         False        6
# male    False       91
#         True        17
# Name: Survived, dtype: int64

# %%
filter3 = df[df['Pclass'] == 3]
titanic3 = filter3.groupby('Sex')['Survived'].value_counts()

plt.pie(titanic3, autopct='%1.0f%%', # Got some of this from here https://www.pythoncharts.com/matplotlib/pie-chart-matplotlib/
        labels = ['Females Survived', 'Females Died', 'Males Died', 'Males Survived'],
        explode = (0, 0, 0, 0))
plt.tight_layout()
plt.title('Rate of Survival in Class 3 by Gender')
plt.rcParams['patch.linewidth'] = 1 # Got this line of code from here: https://stackoverflow.com/questions/20551477/changing-line-properties-in-matplotlib-pie-chart

# %%
titanic3
# Out:
# Sex     Survived
# female  False        72
#         True         72
# male    False       300
#         True         47
# Name: Survived, dtype: int64

# %%
filter.groupby('Sex')['Survived'].value_counts()
# Out:
# Sex     Survived
# female  True        89
#         False        3
# male    False       77
#         True        45
# Name: Survived, dtype: int64

# %% [markdown]
# Saving df to its own file

# %%
df.to_csv(f"updated.csv", index=False)
